# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
v = np.linspace(-5, 5, 100)

phi_1 = [0 if (i <= 0) else i for i in v]
plt.plot(v, phi_1)
plt.xlabel("x")
plt.ylabel("y")
# Out:
# Text(0, 0.5, 'y')

# %%
phi_2 = np.tanh(v)
plt.plot(v, phi_2)
plt.xlabel("x")
plt.ylabel("y")
# Out:
# Text(0, 0.5, 'y')
