# %%
import torch

# Alternative 1: we explicilty write each parameter as an argument
def model_1(x, a, b):
    fx = torch.pow((x - a), 2) + b
    return fx

# %%
# Alternative 2: we store all parameters inside a single tensor argument w
def model_2(x, w):
    a = w[0]
    b = w[1]
    fx = torch.pow((x - a), 2) + b
    return fx

# %%
xt = torch.linspace(start = 0, end = 10, steps = 100)

# %%
import matplotlib.pyplot as plt

# Alternative 1
a = 0
b = 10
y_pred1 = model_1(xt, a, b)

plt.plot(xt, y_pred1)

w = [0, 15]
y_pred2 = model_2(xt, w)

plt.plot(xt, y_pred2)

# %% [markdown]
# # 5.3 Exercises
# <br>
# The following problems are about how model parameters may influnce resulting graphs.

# %% [markdown]
# ## 1.
# For each parameteric prediction model above, make one graph per parameter. For
# every such plot you should show serveral curves corresponding to different values of that parameter, while all other parameters are kept fixed. Make plots containing results for at least 5 different sets of parameter-values. For each one of the models, describe the overall geometrical shape and "location", and then also try to find out how each parameters can be used to alster the shape and "location".

# %% [markdown]
# 1. The plain linear model:

# %%
import torch
import matplotlib.pyplot as plt

def model_1(x, w):
    a = w[0]
    b = w[1]
    fx = a * x + b
    return fx

xt = torch.linspace(start = 0, end = 10, steps = 100)

w_sets = [[0, 0], [2, 0], [0, 5], [-3, -7], [2, 8]]

y_pred = model_1(xt, w_sets[0])
plt.xlabel("x")
plt.ylabel("y")
plt.plot(xt, y_pred)

y_pred = model_1(xt, w_sets[1])
plt.xlabel("x")
plt.ylabel("y")
plt.plot(xt, y_pred)

y_pred = model_1(xt, w_sets[2])
plt.xlabel("x")
plt.ylabel("y")
plt.plot(xt, y_pred)

y_pred = model_1(xt, w_sets[3])
plt.xlabel("x")
plt.ylabel("y")
plt.plot(xt, y_pred)

y_pred = model_1(xt, w_sets[4])
plt.xlabel("x")
plt.ylabel("y")
plt.plot(xt, y_pred)

plt.legend(labels = ["Parameters: a = {}, b = {}".format(w_sets[0][0], w_sets[0][1]), 
                     "Parameters: a = {}, b = {}".format(w_sets[1][0], w_sets[1][1]), 
                     "Parameters: a = {}, b = {}".format(w_sets[2][0], w_sets[2][1]), 
                     "Parameters: a = {}, b = {}".format(w_sets[3][0], w_sets[3][1]), 
                     "Parameters: a = {}, b = {}".format(w_sets[4][0], w_sets[4][1])], 
           loc = "best")

# %% [markdown]
# 2. Two parameter quadratic (parabolic) model:

# %%
import torch
import matplotlib.pyplot as plt

def model_2(x, w):
    a = w[0]
    b = w[1]
    fx = torch.pow((x - a), 2) + b
    return fx

xt = torch.linspace(start = -10, end = 10, steps = 100)

w_sets = [[0, 0], [2, 0], [0, 3], [-3, -5], [2, 3]]

for w in w_sets:
    y_pred = model_2(xt, w)
    plt.xlabel("x")
    plt.ylabel("y")
    plt.xlim(-5, 10)
    plt.ylim(0, 10)
    plt.plot(xt, y_pred)

plt.legend(labels = ["Parameters: a = {}, b = {}".format(w_sets[0][0], w_sets[0][1]), 
                     "Parameters: a = {}, b = {}".format(w_sets[1][0], w_sets[1][1]), 
                     "Parameters: a = {}, b = {}".format(w_sets[2][0], w_sets[2][1]), 
                     "Parameters: a = {}, b = {}".format(w_sets[3][0], w_sets[3][1]), 
                     "Parameters: a = {}, b = {}".format(w_sets[4][0], w_sets[4][1])], 
           loc = "best")

# %% [markdown]
# 3. Michaelis-Menten type model:

# %%
import torch
import matplotlib.pyplot as plt

def model_3(x, w):
    a = w[0]
    b = w[1]
    fx = (a * x) / (b + x)
    return fx

xt = torch.linspace(start = 0, end = 10, steps = 100)

w_sets = [[0, 0], [2, 0], [0, 2], [2, 2], [2, 7], [10, 1]]

for w in w_sets:
    y_pred = model_3(xt, w)
    plt.xlabel("x")
    plt.ylabel("y")
    plt.xlim(-1, 10)
    plt.ylim(-1, 15)
    plt.plot(xt, y_pred)

plt.legend(labels = ["Parameters: a = {}, b = {}".format(w_sets[0][0], w_sets[0][1]), 
                     "Parameters: a = {}, b = {}".format(w_sets[1][0], w_sets[1][1]), 
                     "Parameters: a = {}, b = {}".format(w_sets[2][0], w_sets[2][1]), 
                     "Parameters: a = {}, b = {}".format(w_sets[3][0], w_sets[3][1]), 
                     "Parameters: a = {}, b = {}".format(w_sets[4][0], w_sets[4][1]),
                     "Parameters: a = {}, b = {}".format(w_sets[5][0], w_sets[5][1])], 
           loc = "best")

# %% [markdown]
# 4. Arrhenius type model:

# %%
import torch
import matplotlib.pyplot as plt

def model_4(x, w):
    a = w[0]
    b = w[1]
    fx = a * torch.exp(-(b / x))
    return fx

xt = torch.linspace(start = 0, end = 10, steps = 100)

w_sets = [[0, 0], [2, 0], [0, 2], [2, 2], [2, 7], [10, 1]]

for w in w_sets:
    y_pred = model_4(xt, w)
    plt.xlabel("x")
    plt.ylabel("y")
    plt.xlim(-1, 10)
    plt.ylim(-1, 13)
    plt.plot(xt, y_pred)

plt.legend(labels = ["Parameters: a = {}, b = {}".format(w_sets[0][0], w_sets[0][1]), 
                     "Parameters: a = {}, b = {}".format(w_sets[1][0], w_sets[1][1]), 
                     "Parameters: a = {}, b = {}".format(w_sets[2][0], w_sets[2][1]), 
                     "Parameters: a = {}, b = {}".format(w_sets[3][0], w_sets[3][1]), 
                     "Parameters: a = {}, b = {}".format(w_sets[4][0], w_sets[4][1]),
                     "Parameters: a = {}, b = {}".format(w_sets[5][0], w_sets[5][1])], 
           loc = "best")

# %% [markdown]
# 5. "Bell-curve" type model:

# %%
import torch
import matplotlib.pyplot as plt

def model_5(x, w):
    a = w[0]
    m = w[1]
    v = w[2]
    fx = a * torch.exp(-torch.pow(x - m, 2) / v)
    return fx

xt = torch.linspace(start = -10, end = 10, steps = 100)

w_sets = [[5, 5, 5], [5, 5, 1], [5, 0, 5], [0, 5, 5]]

for w in w_sets:
    y_pred = model_5(xt, w)
    plt.xlabel("x")
    plt.ylabel("y")
    plt.xlim(-10, 10)
    plt.ylim(-2, 6)
    plt.plot(xt, y_pred)

plt.legend(labels = ["Parameters: a = {}, m = {}, v = {}".format(w_sets[0][0], w_sets[0][1], w_sets[0][2]), 
                     "Parameters: a = {}, m = {}, v = {}".format(w_sets[1][0], w_sets[1][1], w_sets[1][2]), 
                     "Parameters: a = {}, m = {}, v = {}".format(w_sets[2][0], w_sets[2][1], w_sets[2][2]), 
                     "Parameters: a = {}, m = {}, v = {}".format(w_sets[3][0], w_sets[3][1], w_sets[3][2])], 
           loc = "best")

# %% [markdown]
# 6. Bimodal "sum-of-two-bell-curves" type model:

# %%
import torch
import matplotlib.pyplot as plt

def model_6(x, w):
    a_1 = w[0]
    m_1 = w[1]
    v_1 = w[2]
    a_2 = w[3]
    m_2 = w[4]
    v_2 = w[5]
    fx = a_1 * torch.exp(-torch.pow(x - m_1, 2) / v_1) + a_2 * torch.exp(-torch.pow(x - m_2, 2) / v_2)
    return fx

xt = torch.linspace(start = -10, end = 30, steps = 200)

w_sets = [[2, 2, 2, 2, 2, 2], 
          [2, 10, 2, 2, 2, 2], [2, 2, 10, 2, 2, 2], 
          [2, 2, 2, 6, 2, 2], [2, 2, 2, 2, 10, 2], 
          [2, 2, 2, 2, 2, 10], [2, 20, 10, 2, 2, 20]]

for w in w_sets:
    y_pred = model_6(xt, w)
    plt.xlabel("x")
    plt.ylabel("y")
    plt.xlim(-10, 33)
    plt.ylim(-1, 10)
    plt.legend(labels = ["Parameters: a1 = {}, m1 = {}, v1 = {}, a2 = {}, m2 = {}, v2 = {}".format(w_sets[0][0], w_sets[0][1], w_sets[0][2], w_sets[0][3], w_sets[0][4], w_sets[0][5]),
    "Parameters: a1 = {}, m1 = {}, v1 = {}, a2 = {}, m2 = {}, v2 = {}".format(w_sets[1][0], w_sets[1][1], w_sets[1][2], w_sets[1][3], w_sets[1][4], w_sets[1][5]),
    "Parameters: a1 = {}, m1 = {}, v1 = {}, a2 = {}, m2 = {}, v2 = {}".format(w_sets[2][0], w_sets[2][1], w_sets[2][2], w_sets[2][3], w_sets[2][4], w_sets[2][5]),
    "Parameters: a1 = {}, m1 = {}, v1 = {}, a2 = {}, m2 = {}, v2 = {}".format(w_sets[3][0], w_sets[3][1], w_sets[3][2], w_sets[3][3], w_sets[3][4], w_sets[3][5]),
    "Parameters: a1 = {}, m1 = {}, v1 = {}, a2 = {}, m2 = {}, v2 = {}".format(w_sets[4][0], w_sets[4][1], w_sets[4][2], w_sets[4][3], w_sets[4][4], w_sets[4][5]),
    "Parameters: a1 = {}, m1 = {}, v1 = {}, a2 = {}, m2 = {}, v2 = {}".format(w_sets[5][0], w_sets[5][1], w_sets[5][2], w_sets[5][3], w_sets[5][4], w_sets[5][5]),
    "Parameters: a1 = {}, m1 = {}, v1 = {}, a2 = {}, m2 = {}, v2 = {}".format(w_sets[6][0], w_sets[6][1], w_sets[6][2], w_sets[6][3], w_sets[6][4], w_sets[6][5])], loc = "best")
    
    plt.plot(xt, y_pred)
plt.figure(figsize=(30, 40))

# %% [markdown]
# ## 2.
# Try to guess suitable parameter values for each of the bell curves in Fig.3. Plot your curves and demonstrate if/that you get back a plot that looks like Fig.3.

# %%
import torch
import matplotlib.pyplot as plt

def model_5(x, w):
    a = w[0]
    m = w[1]
    v = w[2]
    fx = a * torch.exp(-torch.pow(x - m, 2) / v)
    return fx

xt = torch.linspace(start = -12, end = 12, steps = 200)

w = [1, 0, 50]
y_pred = model_5(xt, w)
plt.xlim(-15, 15)
plt.ylim(0, 5)
plt.xlabel("x")
plt.ylabel("y")
plt.plot(xt, y_pred, label = "a = {}, m = {}, v = {}".format(w[0], w[1], w[2]))

w = [1, 0, 10]
y_pred = model_5(xt, w)
plt.plot(xt, y_pred, label = "a = {}, m = {}, v = {}".format(w[0], w[1], w[2]))

w = [1, 3.5, 10]
y_pred = model_5(xt, w)
plt.plot(xt, y_pred, label = "a = {}, m = {}, v = {}".format(w[0], w[1], w[2]))

w = [4, 3, 10]
y_pred = model_5(xt, w)
plt.plot(xt, y_pred, label = "a = {}, m = {}, v = {}".format(w[0], w[1], w[2]))
plt.legend()
plt.show()

# %% [markdown]
# ## 3.
# (a) For each of the 3 datasets A, B and C plotted below, try to guess based on your visual inspaction only, an apropriate model family type and associated suitable parameter values that would result in a reasonably good fit to the data.

# %% [markdown]
# For dataset A, "Bell-curve" type model would be good.
# <br>
# For dataset B, two parameter quadratic (parabolic) model would be good.
# <br>
# For dataset C, the plain linear model would be good.

# %% [markdown]
# (b) Plot the curve for the model and associated parameter values you selected in each case.

# %%
import torch
import matplotlib.pyplot as plt

# For dataset A, the model fitting:
def model_A(x, w):
    a = w[0]
    m = w[1]
    v = w[2]
    fx = a * torch.exp(-torch.pow(x - m, 2) / v)
    return fx

xt = torch.linspace(0, 15, 200)
w = [2.2, 7.6, 2.5]
y_pred = model_A(xt, w)
plt.xlabel("x")
plt.ylabel("y")
plt.ylim(-0.5, 2.5)
plt.title("Dataset A: fitting curve, a = {}, m = {}, v = {}".format(w[0], w[1], w[2]))
plt.plot(xt, y_pred)
plt.show()

# For dataset B, the model fitting:
def model_B(x, w):
    a = w[0]
    b = w[1]
    fx = torch.pow((x - a), 2) + b
    return fx

xt = torch.linspace(-5, 12.5, 200)
w = [3.75, 5]
y_pred = model_B(xt, w)
plt.xlabel("x")
plt.ylabel("y")
plt.ylim(0, 80)
plt.title("Dataset B: fitting curve, a = {}, b = {}".format(w[0], w[1]))
plt.plot(xt, y_pred)
plt.show()

# For dataset C, the model fitting:
def model_C(x, w):
    a = w[0]
    b = w[1]
    fx = a * x + b
    return fx

xt = torch.linspace(0, 15, 200)
w = [0.5, 0.2]
y_pred = model_C(xt, w)
plt.xlabel("x")
plt.ylabel("y")
plt.title("Dataset C: fitting curve, a = {}, b = {}".format(w[0], w[1]))
plt.plot(xt, y_pred)
plt.show()
